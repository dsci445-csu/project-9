# %%
import pandas as pd
import numpy as np 
from statistics import mean
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Goal: Linear Model Predicting W/L based on Events
#
# To accomplish this, we will compress the events in each game to singular features.
#
# For each player, `p`, in each match, `m`, we'll end up with:

# %%
timelines_data = pd.read_json("data/timelines_wv5j6VBEmzdK2utXs45NnlvPvwRXMOsBEHIP6zAME2UE5yWGQnO4QGdPES59nYZ3smWsod2ne8IVZQ.jsonl", lines = True)
timelines = pd.DataFrame(timelines_data['info'].to_list())
frames = timelines[timelines['frames'].apply(lambda x: len(x) > 15)]['frames']

# %%
n = len(frames)
frames[n][15]['events'][0]
# Out:
# {'itemId': 3067,
#  'participantId': 10,
#  'timestamp': 840433,
#  'type': 'ITEM_DESTROYED'}

# %%
frames_flat = []

for game_frame in frames:
    flat = []
    for time in game_frame:
        for event in time['events']:
            flat.append(event)
    frames_flat.append(flat)
