# %%
from matchcleaner import unpack, mergeclean
import pandas as pd
import numpy as np

# %%
df = mergeclean("data/d2_250_1_timelines.jsonl", "data/d2_250_1_matches.jsonl")
df = unpack(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = mergeclean("data/d2_250_1_timelines.jsonl", "data/d2_250_1_matches.jsonl")
#       2 df = unpack(df)
#
# File /workspaces/project-9/matchcleaner.py:4, in mergeclean(timelines_path, matches_path)
#       3 def mergeclean(timelines_path: str, matches_path:str):
# ----> 4     timelines_data = pd.read_json(timelines_path, lines = True)
#       5     timelines_data = pd.DataFrame(timelines_data['info'].to_list())
#       7     matches_data = pd.read_json(matches_path, lines = True)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df = df.drop(columns="champion")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = df.drop(columns="champion")
#
# NameError: name 'df' is not defined

# %%
df.to_csv("data/d2_250_performance.csv", index=False)
