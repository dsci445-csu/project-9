# %%
from matchcleaner import unpack, mergeclean
import pandas as pd
import numpy as np

# %%
df = mergeclean("data/d2_250_1_timelines.jsonl", "data/d2_250_1_matches.jsonl")
df = unpack(df)

# %%
df.head()
# Out:
#    deaths  dragonKills  baronKills  firstBloodKill  firstBloodAssist  kills  \
# 0       8            0           0           False             False      3
# 1      12            1           0           False             False      6
# 2       5            0           0           False             False      4
# 3       6            0           0           False             False      3
# 4       7            0           0           False             False      0
#
#      lane  neutralMinionsKilled  turretTakedowns  turretsLost  ...  \
# 0     TOP                     4                1           11  ...
# 1  JUNGLE                   143                0           11  ...
# 2  MIDDLE                     8                3           11  ...
# 3  BOTTOM                     0                0           11  ...
# 4  MIDDLE                     0                0           11  ...
#
#    enemyMissingPings  clearedPings  totalPings  wardsPlaced  wardsKilled  \
# 0                  4             0           8            2            2
# 1                  3             0          37            1            9
# 2                  2             0           5           10            6
# 3                 25             0          66           10            4
# 4                 16             0          55           28            5
#
#    detectorPlaced  position  duration  champion    win
# 0               1      SOLO      1824      Sion  False
# 1               0      NONE      1824     Sylas  False
# 2               1     CARRY      1824   Caitlyn  False
# 3               0      SOLO      1824     Sivir  False
# 4               4   SUPPORT      1824    Soraka  False
#
# [5 rows x 23 columns]

# %%
df.to_csv("data/d2_250_performance.csv", index=False)
